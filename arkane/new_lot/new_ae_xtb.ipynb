# %% [markdown]
# # Script to add atomization energy (AE) corrections for new level of theory in Arkane
# ## Start Here (do AE before BAC)
#
# See documentation for current levels of theory: https://github.com/ReactionMechanismGenerator/RMG-Py/blob/2a1f9100390fc2ef1b8a8102925d06b941695a25/documentation/source/users/arkane/input.rst#L57
#
# This paper explains atomization energy corrections and bond additivity corrections:
# https://onlinelibrary.wiley.com/doi/10.1002/kin.21637

# %% [markdown]
# # Step 1: Load reference database

# %%
import os

import ase
import ase.io.turbomole

import rmgpy.species

import arkane.encorr.data as data
import arkane.encorr.reference
import arkane.modelchem

import arkane.encorr.ae

import arkane.ess.xtb

import subprocess

# %%
ref_db = arkane.encorr.reference.ReferenceDatabase()
ref_db.load()
# Out:
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# [18:23:17] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p2 c0 {2,S} {3,S}
# 2 O u0 p3 c-1 {1,S}
# 3 C u0 p0 c0 {1,S} {4,S} {5,S} {6,S}
# 4 H u0 p0 c0 {3,S}
# 5 H u0 p0 c0 {3,S}
# 6 H u0 p0 c0 {3,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# [18:23:24] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1  O u0 p3 c-1 {2,S}
# 2  C u0 p0 c0 {1,S} {3,D} {7,S}
# 3  C u0 p0 c0 {2,D} {4,S} {8,S}
# 4  C u0 p0 c0 {3,S} {5,D} {9,S}
# 5  C u0 p0 c0 {4,D} {6,S} {10,S}
# 6  C u0 p0 c0 {5,S} {7,D} {11,S}
# 7  C u0 p0 c0 {2,S} {6,D} {12,S}
# 8  H u0 p0 c0 {3,S}
# 9  H u0 p0 c0 {4,S}
# 10 H u0 p0 c0 {5,S}
# 11 H u0 p0 c0 {6,S}
# 12 H u0 p0 c0 {7,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1); O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1); O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:23:28] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 N u0 p0 c+1 {2,T} {3,S}
# 2 N u0 p1 c0 {1,T}
# 3 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:23:30] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {3,S}
# 2 O u0 p2 c0 {3,D}
# 3 C u0 p0 c0 {1,S} {2,D} {4,S}
# 4 H u0 p0 c0 {3,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# [18:23:34] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 N u0 p0 c+1 {2,S} {3,S} {4,S} {5,S}
# 2 H u0 p0 c0 {1,S}
# 3 H u0 p0 c0 {1,S}
# 4 H u0 p0 c0 {1,S}
# 5 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:23:38] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {2,S}
# 2 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:23:42] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p2 c0 {2,S} {3,S}
# 2 O u0 p3 c-1 {1,S}
# 3 H u0 p0 c0 {1,S}
# [18:23:42] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p1 c+1 {2,S} {3,S} {4,S}
# 2 H u0 p0 c0 {1,S}
# 3 H u0 p0 c0 {1,S}
# 4 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# [18:23:44] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {3,S}
# 2 O u0 p2 c0 {3,D}
# 3 N u0 p1 c0 {1,S} {2,D}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)

# %% [markdown]
# # Step 2: Set up and run calculations using reference data's geometries

# %%
start_dir = '/home/moon/rmg/rmg_tools/arkane/new_lot/'
working_dir = os.path.abspath(os.path.join(start_dir, 'ae_calcs', 'xtb'))
os.makedirs(working_dir, exist_ok=True)
os.chdir(working_dir)

lot = arkane.modelchem.LevelOfTheory(
    method='xtb',
    basis=None,
    software='xtb'
)


sp_indices = []

for i in range(len(ref_db.reference_sets['main'])):
    
    # only do the reference species
    if ref_db.reference_sets['main'][i].label not in arkane.encorr.ae.SPECIES_LABELS:
        continue
    sp_indices.append(i)
    sp_dir = os.path.join(working_dir, f'species_{i:04}')
    os.makedirs(sp_dir, exist_ok=True)
    
    # Use the CCCBDB geometries for energy calculations - see Notes in AEJob class description
    syms = ref_db.reference_sets['main'][i].reference_data['CCCBDB'].xyz_dict['symbols']
    xyz = ref_db.reference_sets['main'][i].reference_data['CCCBDB'].xyz_dict['coords']
    atoms = ase.Atoms(symbols=syms, positions=xyz)
    
    s = rmgpy.species.Species().from_adjacency_list(ref_db.reference_sets['main'][i].adjacency_list)

    geometry_file = os.path.abspath(os.path.join(sp_dir, 'sp.coord'))
    os.chdir(sp_dir)
    with open(geometry_file, 'w') as f:
        ase.io.turbomole.write_turbomole(f, atoms)

    # run xtb
    logfile = os.path.join(sp_dir, 'xtb_results.log')
    with open(logfile, 'w') as f:
        subprocess.check_call(['xtb', '--chrg', str(s.get_net_charge()), '--uhf', str(s.multiplicity - 1), geometry_file], stdout=f, stderr=f)

# %% [markdown]
# # Step 3 - grab the energies for the species_energies dictionary

# %%
species_energies = {}
for i in sp_indices:
    # get the xtb logfile
    logfile = os.path.join(working_dir, f'species_{i:04}', 'xtb_results.log')
    
    with open(logfile, 'r') as f:
        xtb_log = arkane.ess.xtb.XTBLog(logfile)
        # Notes from arkane.encorr.ae say ZPE should not be included
        # arkane.ess.gaussian comments say ZPE is not included
        energy = xtb_log.load_energy() / 2625500  # convert to Hartrees
        species_energies[ref_db.reference_sets['main'][i].label] = energy

# %%
species_energies
# Out:
# {'Ammonia': -4.426176434388473,
#  'Dichlorine': -9.079062669380702,
#  'Dioxygen': -7.904110188666491,
#  'Chloromethane': -8.208566571304079,
#  'Hydrogen chloride': -5.052810775676629,
#  'Disulfur': -6.476384449754554,
#  'Dinitrogen': -5.76393402553289,
#  'Hydrogen bromide': -4.588658532445102,
#  'Difluorine': -9.31933125932301,
#  'Water': -5.07037048832134,
#  'Dibromine': -8.173399565006221,
#  'Dihydrogen': -0.982038377202289,
#  'Hydrogen fluoride': -5.22263902536296,
#  'Hydrogen sulfide': -4.256217482123194,
#  'Methane': -4.175157242736125,
#  'Methyl': -3.5627069115727874}

# %%
# write the arkane ae job file (or I could do this in the code...)
ae_jobfile = os.path.join(working_dir, 'input.py')


with open(ae_jobfile, 'w') as f:
    f.write("""title = 'Atom energy correction fitting for """ + f'{lot.method}/{lot.basis} ' + """level of theory'

lot = LevelOfTheory(\n""" +
f"    method='{lot.method}',\n" +
f"    basis='{lot.basis}',\n" +
f"    software='{lot.software}'\n" +
"""
)

""" + 

f"species_energies={species_energies}\n" + 

"""
ae(
    species_energies=species_energies,
    level_of_theory=lot,
    write_to_database=False,
    overwrite=False
)

""")

# %%
# same thing as the job above, but in code
ae_job = arkane.encorr.ae.AEJob(
    species_energies=species_energies,
    level_of_theory=lot,
    write_to_database=False,
    overwrite=False
)
ae_job.execute()
# Out:
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# [18:23:50] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p2 c0 {2,S} {3,S}
# 2 O u0 p3 c-1 {1,S}
# 3 C u0 p0 c0 {1,S} {4,S} {5,S} {6,S}
# 4 H u0 p0 c0 {3,S}
# 5 H u0 p0 c0 {3,S}
# 6 H u0 p0 c0 {3,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# [18:23:57] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1  O u0 p3 c-1 {2,S}
# 2  C u0 p0 c0 {1,S} {3,D} {7,S}
# 3  C u0 p0 c0 {2,D} {4,S} {8,S}
# 4  C u0 p0 c0 {3,S} {5,D} {9,S}
# 5  C u0 p0 c0 {4,D} {6,S} {10,S}
# 6  C u0 p0 c0 {5,S} {7,D} {11,S}
# 7  C u0 p0 c0 {2,S} {6,D} {12,S}
# 8  H u0 p0 c0 {3,S}
# 9  H u0 p0 c0 {4,S}
# 10 H u0 p0 c0 {5,S}
# 11 H u0 p0 c0 {6,S}
# 12 H u0 p0 c0 {7,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1); O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S(1); O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:24:01] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 N u0 p0 c+1 {2,T} {3,S}
# 2 N u0 p1 c0 {1,T}
# 3 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:24:03] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {3,S}
# 2 O u0 p2 c0 {3,D}
# 3 C u0 p0 c0 {1,S} {2,D} {4,S}
# 4 H u0 p0 c0 {3,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3);
# [18:24:07] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 N u0 p0 c+1 {2,S} {3,S} {4,S} {5,S}
# 2 H u0 p0 c0 {1,S}
# 3 H u0 p0 c0 {1,S}
# 4 H u0 p0 c0 {1,S}
# 5 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:24:11] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {2,S}
# 2 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# [18:24:16] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p2 c0 {2,S} {3,S}
# 2 O u0 p3 c-1 {1,S}
# 3 H u0 p0 c0 {1,S}
# [18:24:16] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p1 c+1 {2,S} {3,S} {4,S}
# 2 H u0 p0 c0 {1,S}
# 3 H u0 p0 c0 {1,S}
# 4 H u0 p0 c0 {1,S}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# [18:24:18] WARNING: Proton(s) added/removed
#
# ERROR:root:Unable to generate identifier for this molecule:
# 1 O u0 p3 c-1 {3,S}
# 2 O u0 p2 c0 {3,D}
# 3 N u0 p1 c0 {1,S} {2,D}
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)

# %%
ae_job.ae.atom_energies
# Out:
# {'H': -0.4097990033103076,
#  'C': -1.857369943688362,
#  'N': -2.704553488231256,
#  'O': -3.8611287247907726,
#  'F': -4.620902022430577,
#  'S': -3.1548542838674423,
#  'Cl': -4.490051580163835,
#  'Br': -4.047055878763101}

# %%
ae_job.ae.confidence_intervals
# Out:
# {'H': 0.01031922551141431,
#  'C': 0.04400908968013249,
#  'N': 0.021933263328368674,
#  'O': 0.021442265673209004,
#  'F': 0.021142194478857356,
#  'S': 0.021442265673209004,
#  'Cl': 0.01980203434101946,
#  'Br': 0.021142194478857353}

# %%
ae_job.ae.atom_energies.keys()
# Out:
# dict_keys(['H', 'C', 'N', 'O', 'F', 'S', 'Cl', 'Br'])

# %% [markdown]
# # Copy formatted energies into database

# %%
# add these to the atom_energies dictionary in RMG-database/input/quantum_corrections/data.py

for atom in ae_job.ae.atom_energies.keys():
    print(f'# {atom}\t{ae_job.ae.atom_energies[atom]:.8f}\t+/- {ae_job.ae.confidence_intervals[atom]:.8f} Hartree')

print(f'"{lot} ":','{')


for atom in ae_job.ae.atom_energies.keys():
    # Pretty sure SOC needs to get added here and hasn't been accounted for in the fitting process
    print(f'    "{atom}": {ae_job.ae.atom_energies[atom]} + SOC["{atom}"],')

print('},')
# ae_job.ae.atom_energies
# Out:
# # H	-0.40979900	+/- 0.01031923 Hartree
# # C	-1.85736994	+/- 0.04400909 Hartree
# # N	-2.70455349	+/- 0.02193326 Hartree
# # O	-3.86112872	+/- 0.02144227 Hartree
# # F	-4.62090202	+/- 0.02114219 Hartree
# # S	-3.15485428	+/- 0.02144227 Hartree
# # Cl	-4.49005158	+/- 0.01980203 Hartree
# # Br	-4.04705588	+/- 0.02114219 Hartree
# "LevelOfTheory(method='xtb',software='xtb') ": {
#     "H": -0.4097990033103076 + SOC["H"],
#     "C": -1.857369943688362 + SOC["C"],
#     "N": -2.704553488231256 + SOC["N"],
#     "O": -3.8611287247907726 + SOC["O"],
#     "F": -4.620902022430577 + SOC["F"],
#     "S": -3.1548542838674423 + SOC["S"],
#     "Cl": -4.490051580163835 + SOC["Cl"],
#     "Br": -4.047055878763101 + SOC["Br"],
# },
